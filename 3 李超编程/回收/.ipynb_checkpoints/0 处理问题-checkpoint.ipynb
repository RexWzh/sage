# %%
import sympy
from sympy.matrices import Matrix #最后处理矩阵用
#导入工具包
load('Lie.sage') #李代数相关的工具
load('spo.sage') #李超代数spo的工具
load('MatSp.sage') #处理矩阵的工具
load('AlgebraBSC.sage') #结构常数相关工具
load('pbw.sage') #李代数pbw基的工具
load('pbws.sage') #李超代数pbw基的工具
print('''导入相关工具包：
1. Lie.sage：李代数工具，以及C,D族李代数
2. spo.sage：李超代数工具，以及spo
3. MatSp.sage：矩阵空间，求矩阵关于矩阵基的线性表示
4. AlgebraBSC：求李/李超代数的结构常数，以及由结构常数生成代数
5. pbw.sage/pbws.sage 李/李超代数的pbw基''')
# Out:
# 导入相关工具包：
# 1. Lie.sage：李代数工具，以及C,D族李代数
# 2. spo.sage：李超代数工具，以及spo
# 3. MatSp.sage：矩阵空间，求矩阵关于矩阵基的线性表示
# 4. AlgebraBSC：求李/李超代数的结构常数，以及由结构常数生成代数
# 5. pbw.sage/pbws.sage 李/李超代数的pbw基

# %%
#V初始化数据
t,k = 1,4
L = SpO(t,k) #李超代数
mats = L.negative_matrixs + L.h_matrixs + L.positive_matrixs #矩阵信息
m = len(L.positive_roots)
print('李超代数：spo(%d,%d)\n空间维数为：%d\n正根数目为：%d'%(t,k,len(mats),m))
es = Lie.symbols('e',m)
fs = Lie.symbols('f',m)
hs = Lie.symbols('h',k+1) 
syms = fs + hs +es #用作结构常数的符号变量
#奇根对应的符号变量
roots = L.positive_roots 
ind1 = [roots.index(r) for r in L.odd_roots if r in roots]
roots = L.simple_roots
ind2 = [roots.index(r) for r in L.odd_roots if r in roots]
odds = [fs[i] for i in ind1] + [hs[i] for i in ind2] + [es[i] for i in ind1] 

#由结构常数得到的L一组基
print('计算结构常数，并由结构常数重新生成李超代数')
N = AlgebraBSC.lie_sup_SC(mats,L.odd_mats)
Lf = {i+1:Element(element,N,syms) for i,element in enumerate(fs)}
Le = {i+1:Element(element,N,syms) for i,element in enumerate(es)}
Lh = {i+1:Element(element,N,syms) for i,element in enumerate(hs)}
#pbw基
print('计算李超代数pbw基')
vf = {i+1:SPBWElement(element,N,syms,odds) for i,element in enumerate(fs)}
ve = {i+1:SPBWElement(element,N,syms,odds) for i,element in enumerate(es)}
vh = {i+1:SPBWElement(element,N,syms,odds) for i,element in enumerate(hs)}
vectors = L.vectors
pbw = ve[1].tuple2element
# Out:
# 李超代数：spo(1,4)
# 空间维数为：47
# 正根数目为：21
# 计算结构常数，并由结构常数重新生成李超代数
# 计算李超代数pbw基

# %%
#权的正根分解
weight = L.basis[0] + L.basis[1];print('待讨论的权：',weight) #待讨论的权（正交基形式）
root = L.vector2root(weight) #转单根形式
dec = L.positive_dec(root) #正根分解（元组构成）
negative_roots = L.negative_roots #负根
dec_root = []
for line in dec:
    new = []
    for i,element in enumerate(line):
        if element:
            new = new + [negative_roots[i]]*element
    dec_root.append(tuple(new))
dec_vector = [tuple(L.root2vector(r) for r in line) for line in dec_root]
print('权空间维数：',len(dec)) #分解总数目
#for line in res_vectors:print(line)
table([[i for i in line if i] for line in dec_vector]) #分解结果
# Out:
# 待讨论的权： d + e1
# 权空间维数： 55
#   -d + e1
#   -e1 + e2
#   -d + e1
#   -d + e1
#   -d + e1
#   -e2 + e3
#   -d + e1
#   -d + e1
#   -e1 + e2
#   -e1 + e2
#   -d + e1
#   -d + e1
#   -e1 + e2
#   -d + e1
#   -d + e1
#   -d + e1
#   -e1 + e2
#   -e2 + e3
#   -e3 + e4
#   -e3 - e4
#   -e1 + e2
#   -d + e1
#   -d + e1
#   -d + e1
#   -e1 + e2
#   -e1 + e2
#   -e3 + e4
#   -e1 + e2
#   -d + e1
#   -e2 + e3
#   -e1 + e2
#   -d + e1
#   -d + e1
#   -e1 + e2
#   -e3 + e4
#   -e1 + e2
#   -e3 - e4
#   -d + e2
#   -e3 - e4
#   -d + e2
#   -e2 + e3
#   -d + e1
#   -d + e2
#   -d + e1
#   -e3 + e4
#   -e1 + e2
#   -e1 + e2
#   -d + e1
#   -d + e3
#   -e1 + e2
#   -e1 - e4
#   -e1 + e3
#   -e1 + e4
#   -d + e2
#   -d - e1

# %%
#相应的pbw基
basis = [tuple(fs[negative_roots.index(i)] for i in line) for line in dec_root]
pbw_basis = [pbw(i) for i in basis]
print('权空间对应的pbw基：')
pbw_basis
# Out:
# 权空间对应的pbw基：
# [{(f1, f2^2, f3^2, f4, f5): 1},
#  {(f2, f3^2, f4, f5, f6): 1},
#  {(f1, f2^2, f3, f4, f9): 1},
#  {(f1, f2, f3, f4, f5, f7): 1},
#  {(f1, f2^2, f3, f5, f8): 1},
#  {(f3, f4, f5, f6, f7): 1},
#  {(f1, f2, f4, f7, f9): 1},
#  {(f1, f2^2, f8, f9): 1},
#  {(f2, f3, f4, f5, f10): 1},
#  {(f2, f3, f4, f6, f9): 1},
#  {(f1, f2, f3, f4, f12): 1},
#  {(f1, f4, f5, f7^2): 1},
#  {(f2, f3, f5, f6, f8): 1},
#  {(f1, f2, f5, f7, f8): 1},
#  {(f1, f2, f3, f5, f11): 1},
#  {(f1, f2^2, f3, f13): 1},
#  {(f2, f4, f9, f10): 1},
#  {(f3, f5, f6, f11): 1},
#  {(f4, f5, f7, f10): 1},
#  {(f5, f6, f7, f8): 1},
#  {(f2, f3, f4, f15): 1},
#  {(f1, f2, f8, f12): 1},
#  {(f1, f5, f7, f11): 1},
#  {(f1, f2, f3, f16): 1},
#  {(f2, f5, f8, f10): 1},
#  {(f2, f3, f5, f14): 1},
#  {(f4, f6, f7, f9): 1},
#  {(f2, f3, f6, f13): 1},
#  {(f1, f2, f7, f13): 1},
#  {(f3, f4, f6, f12): 1},
#  {(f2, f6, f8, f9): 1},
#  {(f1, f2, f9, f11): 1},
#  {(f1, f4, f7, f12): 1},
#  {(f2, f10, f13): 1},
#  {(f4, f7, f15): 1},
#  {(f2, f8, f15): 1},
#  {(f5, f10, f11): 1},
#  {(f6, f9, f11): 1},
#  {(f5, f7, f14): 1},
#  {(f6, f8, f12): 1},
#  {(f3, f6, f16): 1},
#  {(f1, f7, f16): 1},
#  {(f6, f7, f13): 1},
#  {(f1, f2, f18): 1},
#  {(f4, f10, f12): 1},
#  {(f2, f9, f14): 1},
#  {(f2, f3, f17): 1},
#  {(f1, f11, f12): 1},
#  {(f10, f16): 1},
#  {(f2, f19): 1},
#  {(f12, f14): 1},
#  {(f7, f17): 1},
#  {(f11, f15): 1},
#  {(f6, f18): 1},
#  {(f20,): 1}]

# %%
#最高权向量
x = Lie.symbols('x',k)
la = (x[0]+6)*L.basis[0] + x[0]*L.basis[1] + x[1]*L.basis[2] + x[2]*L.basis[3] + x[3]*L.basis[4]
print('最高权：',la)

#泛包络上计算结果res
res = [[ve[i]*element for element in pbw_basis] for i in range(1,k+2)]
print("在泛包络上计算，总数：",(k+1)*len(pbw_basis))

#化简为Verma模的元素
res_verma = [[i.to_verma(la,L,k+1) for i in line] for line in res]
res_element = [[i.element for i in line] for line in res_verma] #转化为字典形式
print('已转化为Verma模上的元素')

#转化为矩阵
data = []
for line in res_element:
    keys = set()
    for i in line:
        keys = keys.union(i.keys())
    data.append(matrix([[ele[key] if key in ele else 0 for key in keys] for ele in line]).transpose())
mat = matrix.block(k+1,1,data)
print('已转化为矩阵，阶数为 %dx%d'%mat.dimensions())
mat_sym = Matrix(mat)
print('矩阵的秩为：',mat_sym.rank()) #54打印时间太长了！
# Out:
# 最高权： d*(x1 + 6) + e1*x1 + e2*x2 + e3*x3 + e4*x4
# 在泛包络上计算，总数： 275
# 转化为Verma模上的元素
# 转化为矩阵，阶数为 106x55
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-cad8c568df61> in <module>()
#      23 print('转化为矩阵，阶数为 %dx%d'%mat.dimensions())
#      24 mat_sym = Matrix(mat)
# ---> 25 print('矩阵的秩为：',mat_sym.rank())
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/matrices/matrices.py in rank(self, iszerofunc, simplify)
#     875
#     876         mat, _ = self._permute_complexity_right(iszerofunc=iszerofunc)
# --> 877         echelon_form, pivots, swaps = mat._eval_echelon_form(iszerofunc=iszerofunc, simpfunc=simpfunc)
#     878         return len(pivots)
#     879
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/matrices/matrices.py in _eval_echelon_form(self, iszerofunc, simpfunc)
#     575                                                       normalize_last=True,
#     576                                                       normalize=False,
# --> 577                                                       zero_above=False)
#     578         return reduced, pivot_cols, swaps
#     579
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/matrices/matrices.py in _row_reduce(self, iszerofunc, simpfunc, normalize_last, normalize, zero_above)
#     705             pivot_offset, pivot_val, \
#     706             assumed_nonzero, newly_determined = _find_reasonable_pivot(
# --> 707                 get_col(piv_col)[piv_row:], iszerofunc, simpfunc)
#     708
#     709             # _find_reasonable_pivot may have simplified some things
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/matrices/matrices.py in _find_reasonable_pivot(col, iszerofunc, simpfunc)
#    4757         if possible_zeros[i] is not None:
#    4758             continue
# -> 4759         simped = simpfunc(x)
#    4760         is_zero = iszerofunc(simped)
#    4761         if is_zero == True or is_zero == False:
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse)
#     603
#     604     short = shorter(powsimp(expr, combine='exp', deep=True), powsimp(expr), expr)
# --> 605     short = shorter(short, cancel(short))
#     606     short = shorter(short, factor_terms(short), expand_power_exp(expand_mul(short)))
#     607     if short.has(TrigonometricFunction, HyperbolicFunction, ExpBase):
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/polys/polytools.py in cancel(f, *gens, **args)
#    6604         if f.is_Number or isinstance(f, Relational) or not isinstance(f, Expr):
#    6605             return f
# -> 6606         f = factor_terms(f, radical=True)
#    6607         p, q = f.as_numer_denom()
#    6608
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/exprtools.py in factor_terms(expr, radical, clear, fraction, sign)
#    1200         return rv
#    1201     expr = sympify(expr)
# -> 1202     return do(expr)
#    1203
#    1204
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/exprtools.py in do(expr)
#    1193                 isprimitive=True,
#    1194                 clear=clear,
# -> 1195                 fraction=fraction).xreplace(special)
#    1196         elif p.args:
#    1197             p = p.func(
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/exprtools.py in gcd_terms(terms, isprimitive, clear, fraction)
#    1061             terms = sympify(terms)
#    1062         terms, reps = mask(terms)
# -> 1063         cont, numer, denom = _gcd_terms(terms, isprimitive, fraction)
#    1064         numer = numer.xreplace(reps)
#    1065         coeff, factors = cont.as_coeff_Mul()
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/exprtools.py in _gcd_terms(terms, isprimitive, fraction)
#     967                 numers.append(term.coeff*numer.as_expr())
#     968         else:
# --> 969             numers = [t.as_expr() for t in terms]
#     970             denom = Term(S(1)).numer
#     971
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/exprtools.py in <listcomp>(.0)
#     967                 numers.append(term.coeff*numer.as_expr())
#     968         else:
# --> 969             numers = [t.as_expr() for t in terms]
#     970             denom = Term(S(1)).numer
#     971
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/exprtools.py in as_expr(self)
#     857
#     858     def as_expr(self):  # Term
# --> 859         return self.coeff*(self.numer.as_expr()/self.denom.as_expr())
#     860
#     861     def mul(self, other):  # Term
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/exprtools.py in as_expr(self)
#     453             else:
#     454                 args.append(factor)
# --> 455         return Mul(*args)
#     456
#     457     def mul(self, other):  # Factors
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/operations.py in __new__(cls, *args, **options)
#      45             return args[0]
#      46
# ---> 47         c_part, nc_part, order_symbols = cls.flatten(args)
#      48         is_commutative = not nc_part
#      49         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/mul.py in flatten(cls, seq)
#     606
#     607         # order commutative part canonically
# --> 608         _mulsort(c_part)
#     609
#     610         # current code expects coeff to be always in slot-0
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/mul.py in _mulsort(args)
#      32 def _mulsort(args):
#      33     # in-place sorting of args
# ---> 34     args.sort(key=_args_sortkey)
#      35
#      36
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/basic.py in compare(self, other)
#     207             r = Basic(*r) if isinstance(r, frozenset) else r
#     208             if isinstance(l, Basic):
# --> 209                 c = l.compare(r)
#     210             else:
#     211                 c = (l > r) - (l < r)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/basic.py in compare(self, other)
#     198             return c
#     199         #
# --> 200         st = self._hashable_content()
#     201         ot = other._hashable_content()
#     202         c = (len(st) > len(ot)) - (len(st) < len(ot))
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/symbol.py in _hashable_content(self)
#     250     def _hashable_content(self):
#     251         # Note: user-specified assumptions not hashed, just derived ones
# --> 252         return (self.name,) + tuple(sorted(self.assumptions0.items()))
#     253
#     254     def _eval_subs(self, old, new):
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/symbol.py in assumptions0(self)
#     260     def assumptions0(self):
#     261         return dict((key, value) for key, value
# --> 262                 in self._assumptions.items() if value is not None)
#     263
#     264     @cacheit
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
def solve_matrix(mat):
    n = len(mat.row(0))
    b = sympy.Matrix([0 for i in range(len(mat.col(0)))]) #零矩阵
    para = sympy.symbols(('y%d '*n)%tuple(range(1,n+1)))
    return sympy.linsolve((mat,b),para)

# %%
solution = solve_matrix(mat_sym) #sage上的运算时间太长了！
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-05aa2afd149a> in <module>()
# ----> 1 solution = solve_matrix(mat_sym)
#
# <ipython-input-14-1884f65d956f> in solve_matrix(mat)
#       3     b = sympy.Matrix([Integer(0) for i in range(len(mat.col(Integer(0))))]) #零矩阵
#       4     para = sympy.symbols(('y%d '*n)%tuple(range(Integer(1),n+Integer(1))))
# ----> 5     return sympy.linsolve((mat,b),para)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/solvers/solveset.py in linsolve(system, *symbols)
#    2198
#    2199     try:
# -> 2200         solution, params, free_syms = A.gauss_jordan_solve(b, freevar=True)
#    2201     except ValueError:
#    2202         # No solution
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/matrices/matrices.py in gauss_jordan_solve(self, B, freevar)
#    2976
#    2977         # solve by reduced row echelon form
# -> 2978         A, pivots = aug.rref(simplify=True)
#    2979         A, v = A[:, :-B_cols], A[:, -B_cols:]
#    2980         pivots = list(filter(lambda p: p < col, pivots))
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/matrices/matrices.py in rref(self, iszerofunc, simplify, pivots, normalize_last)
#     934         ret, pivot_cols = self._eval_rref(iszerofunc=iszerofunc,
#     935                                           simpfunc=simpfunc,
# --> 936                                           normalize_last=normalize_last)
#     937         if pivots:
#     938             ret = (ret, pivot_cols)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/matrices/matrices.py in _eval_rref(self, iszerofunc, simpfunc, normalize_last)
#     589         reduced, pivot_cols, swaps = self._row_reduce(iszerofunc, simpfunc,
#     590                                                       normalize_last, normalize=True,
# --> 591                                                       zero_above=True)
#     592         return reduced, pivot_cols
#     593
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/matrices/matrices.py in _row_reduce(self, iszerofunc, simpfunc, normalize_last, normalize, zero_above)
#     705             pivot_offset, pivot_val, \
#     706             assumed_nonzero, newly_determined = _find_reasonable_pivot(
# --> 707                 get_col(piv_col)[piv_row:], iszerofunc, simpfunc)
#     708
#     709             # _find_reasonable_pivot may have simplified some things
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/matrices/matrices.py in _find_reasonable_pivot(col, iszerofunc, simpfunc)
#    4757         if possible_zeros[i] is not None:
#    4758             continue
# -> 4759         simped = simpfunc(x)
#    4760         is_zero = iszerofunc(simped)
#    4761         if is_zero == True or is_zero == False:
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse)
#     558     expr = bottom_up(expr, lambda w: getattr(w, 'normal', lambda: w)())
#     559     expr = Mul(*powsimp(expr).as_content_primitive())
# --> 560     _e = cancel(expr)
#     561     expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#     562     expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/polys/polytools.py in cancel(f, *gens, **args)
#    6615
#    6616     try:
# -> 6617         (F, G), opt = parallel_poly_from_expr((p, q), *gens, **args)
#    6618     except PolificationFailed:
#    6619         if not isinstance(f, (tuple, Tuple)):
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/polys/polytools.py in parallel_poly_from_expr(exprs, *gens, **args)
#    4307     """Construct polynomials from expressions. """
#    4308     opt = options.build_options(gens, args)
# -> 4309     return _parallel_poly_from_expr(exprs, opt)
#    4310
#    4311
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/polys/polytools.py in _parallel_poly_from_expr(exprs, opt)
#    4346
#    4347                 if opt.expand:
# -> 4348                     expr = expr.expand()
#    4349         else:
#    4350             failed = True
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/expr.py in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3198             if hints.get('mul', False):
#    3199                 expr, _ = Expr._expand_hint(
# -> 3200                     expr, '_eval_expand_mul', deep=deep, **hints)
#    3201             if hints.get('log', False):
#    3202                 expr, _ = Expr._expand_hint(
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3122             sargs = []
#    3123             for arg in expr.args:
# -> 3124                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3125                 hit |= arghit
#    3126                 sargs.append(arg)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3130
#    3131         if hasattr(expr, hint):
# -> 3132             newexpr = getattr(expr, hint)(**hints)
#    3133             if newexpr != expr:
#    3134                 return (newexpr, True)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/mul.py in _eval_expand_mul(self, **hints)
#     877             if sums:
#     878                 deep = hints.get("deep", False)
# --> 879                 terms = self.func._expandsums(sums)
#     880                 args = []
#     881                 for term in terms:
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/mul.py in _expandsums(sums)
#     843
#     844         terms = [Mul(a, b) for a in left for b in right]
# --> 845         added = Add(*terms)
#     846         return Add.make_args(added)  # it may have collapsed down to one term
#     847
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92             def wrapper(*args, **kwargs):
#      93                 try:
# ---> 94                     retval = cfunc(*args, **kwargs)
#      95                 except TypeError:
#      96                     retval = func(*args, **kwargs)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/operations.py in __new__(cls, *args, **options)
#      45             return args[0]
#      46
# ---> 47         c_part, nc_part, order_symbols = cls.flatten(args)
#      48         is_commutative = not nc_part
#      49         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/add.py in flatten(cls, seq)
#     273
#     274         # order args canonically
# --> 275         _addsort(newseq)
#     276
#     277         # current code expects coeff to be first
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/add.py in _addsort(args)
#      19 def _addsort(args):
#      20     # in-place sorting of args
# ---> 21     args.sort(key=_args_sortkey)
#      22
#      23
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sympy/core/basic.py in compare(self, other)
#     194         n1 = self.__class__
#     195         n2 = other.__class__
# --> 196         c = (n1 > n2) - (n1 < n2)
#     197         if c:
#     198             return c
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
solution = [ - x2 - x3, - 2*x1 - 2, x3 - x2, 5*x1 + x2 + 2*x3 + x1*x2 + x1*x3 + x2*x3 + x1^2 + 4, - x1^2 - 3*x1 + x2^2 + x2 - 2, - x1^2 - 3*x1 + x3^2 - x2 - 2, x2 - 3*x1 + x1*x2 + x1*x3 - x2*x3 - x1^2 - 2, x2 - 3*x1 + x1*x2 - x1*x3 + x2*x3 - x1^2 - 2, 5*x1 + x2 - 2*x3 + x1*x2 - x1*x3 - x2*x3 + x1^2 + 4, 8*x1 - 2*x2 + 2*x3 - 2*x1*x2 + 4*x1*x3 - 2*x2*x3 - x1*x2^2 + x1^2*x3 - x2^2*x3 + 5*x1^2 + x1^3 - x2^2 + 4, x2*x3^2 - x2 - 2*x1*x2 - x1^2*x2 - x1*x3^2 - x1 + 2*x1^2 + x1^3 - 2, 13*x1 + 3*x2 + 4*x1*x2 + x1^2*x2 - x1*x3^2 - x2*x3^2 + 6*x1^2 + x1^3 - 2*x3^2 + 8, 8*x1 - 2*x2 - 2*x3 - 2*x1*x2 - 4*x1*x3 + 2*x2*x3 - x1*x2^2 - x1^2*x3 + x2^2*x3 + 5*x1^2 + x1^3 - x2^2 + 4, x1^4 + 7*x1^3 - x1^2*x2^2 - x1^2*x2 - x1^2*x3^2 + 19*x1^2 - 4*x1*x2^2 - 6*x1*x2 - 3*x1*x3^2 + 23*x1 + x2^2*x3^2 - 3*x2^2 + x2*x3^2 - 5*x2 - 2*x3^2 + 10]
solution = [factor(i) for i in solution]
mat_res = matrix(solution)

# %%
table(mat_res.transpose())
# Out:
# <repr(<sage.misc.table.table at 0x6fba76f5048>) failed: TypeError: object of type 'sage.matrix.matrix_symbolic_dense.Matrix_symbolic_dense' has no len()>

# %%
class Pack():
    '''多数据位置同步
    用于打包数据
    call直接调用其中某一个
    print属性显示里边包含了哪些内容
    
    
    '''
    def __init__(self,*args):
        n = len(args)
        self.args = args
        self.names = ('p%d '*self.n)%tuple(range(1,self.n+1))
        
    def switch(self,a,n,m):
        assert n<=self.n and m<= self.n
        old = self.args[n-1]
        new = self.args[m-1]
        return new[old.index(a)]

# %%
def var2sym(expr,basis1,basis2):
    if isinstance(expr,Integer):return expr
    coef = Lie.coefficients(expr,basis1)
    return sum([i*j for i,j in zip(coef,basis2)])
