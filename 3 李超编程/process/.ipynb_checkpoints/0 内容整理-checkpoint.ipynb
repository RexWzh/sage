# %%
load("Lie.sage")
"""1. Lie.sage 李代数工具
class Lie:
    @property
        negative_roots #（李超可用）
        roots #（李超可用）
        negative_vectors #（李超可用）
        vectors #（李超可用）
        negative_matrixs #（李超重编写）
        matrixs #（李超可用）
    @staticmethod
        coefficients(a,basis) #（李超可用）
        symbols(name,num)  #（李超可用）
        lie_bracket(a,b) #（李超可用）
        #检验函数 h取符号对角阵
        check_weight(h,mat,vec) #检查mat的权是否为vec（李超可用）
        find_weights(h,mat) # 求mat的权（李超可用）
    @classmethod
        transform(vec,tran_mat,basis1,basis2) #坐标变换 #（李超可用）
        odering(basis,roots) #正根排序，ht+单根逆字典序，返回索引 #（李超可用）
        check_weights(h,mats,vectors) #批量检查 （李超可用）
    root2vector(root) #（李超可用）
    vector2root(vec) #（李超可用）
    root2matrix(root) #（李超可用）
    vector2matrix(vec) #（李超可用）
    inner_product(r1,r2,is_root=False) #内积（李超重编写）
    cartan_integer(beta,alpha,is_root=False) #Cartan整数
    positive_dec(root) #正根分解，返回正根的索引元组 （李超可用）

class Sp,Oth: #继承Lie类
    在Lie的基础上，进行了数据初始化（数据可以改用函数，减少初始化时间）
    tran_mat #过渡阵：单根=正交基*mat
    tran_mat_inv #取逆
    simple_roots
    basis #内积空间的基（建议改ambient_basis）
    positive_vectors
    positive_roots
    positive_matrixs
    simple_vectors
    e_matrixs
    f_matrixs
    h_matrixs
    gen_matrixs
    all_matrixs 
    dim #代数空间维数
    diag #对角阵，对角元由ambient_basis构成
数据的序
    simple_roots 按carter第8章的单根顺序
    positive_roots 按单根分解的ht分层，每一层按单根字典序排
    打包关系
        simple_roots,simple_vectors,e_matrixs,f_matirxs,h_matrixs
        positive_vectors,positive_roots,positive_matrixs + negative版本
生成关系
    negative_roots = -positive_roots
    roots = positive_roots + negative_roots
    h_matrixs = [e_matrixs,f_matrixs]
    gen_matrixs = e_matrixs+f_matrixs+h_matrixs
    all_matrixs = matrixs+h_matrixs
测试内容
    略
"""
pass

# %%
load('spo.sage')
'''2. spo.sage 李超代数工具
class SpO:
    继承Lie:
        参看Lie注释
    @property
        negative_matrixs #重编写
    lie_super_b(m1,m2) #仅支持矩阵基上计算
    inner_product(r1,r2,is_root=False) #重编写
    root_on_diag(alpha,h,is_root=True) #根作用对角线上
    super_trace(mat) #超迹
    B(m1,m2) #李超双线性型
    #初始化
    sp,o #李代数sp和o部分
    basis #ambient基（建议改名）
    m,n #相关数值
    simple_vecotrs
    even_vectors,even_roots
    even_mats #（mats，matrixs名称规范下）
    odd_vectors,odd_roots
    simple_roots #按李超Dynkin图
    tran_mat,tran_mat_inv
    positive_roots,positive_vectors,positive_matrixs
    e_matrixs,f_matrixs,h_matrixs
    gen_matrixs
    all_matrixs = matrixs + h_matrixs
    diag #符号阵
    dim #代数空间维数
数据的序
    simple_vectors = sp+o （拼接李代数的序）
    even_mats,even_vectors,even_roots = sp+o
    odd_mats,odd_vectors,odd_roots: di+ej,-di-ej,di-ej,-di+ej，并按(i,j)逆字典序
    positive 和 negative 的序与李代数序定义一致
'''
pass
