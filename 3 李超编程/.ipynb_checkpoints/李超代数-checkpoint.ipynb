# %%
m,n = 1,3
s,t = 1,1
load('zong.sage')
#table([[i for i in line if i] for line in dec_vector]) #分解结果
# Out:
# 导入相关工具包：
# 1. Lie.sage：李代数工具，以及C,D族李代数
# 2. spo.sage：李超代数工具，以及spo
# 3. MatSp.sage：矩阵空间，求矩阵关于矩阵基的线性表示
# 4. AlgebraBSC：求李/李超代数的结构常数，以及由结构常数生成代数
# 5. pbw.sage/pbws.sage 李/李超代数的pbw基
# 6. rex.py 解方程工具
#
# 李超代数：spo(2,6)
# 空间维数为：30
# 正根数目为：13
#
# 计算结构常数
#
# 计算李超代数泛包络的pbw基
# 初始化完毕，用时 3.044s
#
# 待讨论的权： delta + epsilon1
# 权空间维数： 15
# 用时：0.255s
#
# 权空间对应的pbw基：
# {(f1, f2^2, f3, f4): 1}
# {(f1, f2, f3, f7): 1}
# {(f2, f3, f4, f5): 1}
# {(f1, f2, f4, f6): 1}
# {(f2, f3, f9): 1}
# {(f1, f6, f7): 1}
# {(f1, f2, f10): 1}
# {(f3, f5, f7): 1}
# {(f4, f5, f6): 1}
# {(f2, f4, f8): 1}
# {(f6, f9): 1}
# {(f5, f10): 1}
# {(f2, f11): 1}
# {(f7, f8): 1}
# {(f12,): 1}
#
# 最高权： delta*(x1 + 4) + epsilon1*x1 + epsilon2*x2 + epsilon3*x3
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# 计算泛包络上的乘积结果，乘积总数： 60
# 用时：9.041s
#
# 转化为Verma模上结果，用时：2.620s
#
# 矩阵阶数为 23*15  计算用时：0.009s

# %%
mat.rank()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-9c354d61d0f6> in <module>()
# ----> 1 mat.rank()
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/matrix/matrix0.pyx in sage.matrix.matrix0.Matrix.rank (build/cythonized/sage/matrix/matrix0.c:29036)()
#    4342         if self._nrows == 0 or self._ncols == 0:
#    4343             return 0
# -> 4344         r = len(self.pivots())
#    4345         self.cache('rank', r)
#    4346         return r
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/matrix/matrix0.pyx in sage.matrix.matrix0.Matrix.pivots (build/cythonized/sage/matrix/matrix0.c:28737)()
#    4299         x = self.fetch('pivots')
#    4300         if not x is None: return tuple(x)
# -> 4301         self.echelon_form()
#    4302         x = self.fetch('pivots')
#    4303         if x is None:
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix.echelon_form (build/cythonized/sage/matrix/matrix2.c:49385)()
#    6845         E = self.__copy__()
#    6846         if algorithm == 'default':
# -> 6847             v = E.echelonize(cutoff=cutoff, **kwds)
#    6848         else:
#    6849             v = E.echelonize(algorithm = algorithm, cutoff=cutoff, **kwds)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix.echelonize (build/cythonized/sage/matrix/matrix2.c:48771)()
#    6742             if self.base_ring() in _Fields:
#    6743                 if algorithm in ['classical', 'partial_pivoting', 'scaled_partial_pivoting', 'scaled_partial_pivoting_valuation']:
# -> 6744                     self._echelon_in_place(algorithm)
#    6745                 elif algorithm == 'strassen':
#    6746                     self._echelon_strassen(cutoff)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/matrix/matrix2.pyx in sage.matrix.matrix2.Matrix._echelon_in_place (build/cythonized/sage/matrix/matrix2.c:50238)()
#    7007                 sig_check()
#    7008                 for r in range(start_row, nr):
# -> 7009                     if A.get_unsafe(r, c):
#    7010                         pivots.append(c)
#    7011                         a_inverse = ~A.get_unsafe(r, c)
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.__nonzero__ (build/cythonized/sage/symbolic/expression.cpp:19728)()
#    2938             return False
#    2939         else:
# -> 2940             return not bool(self == self._parent.zero())
#    2941
#    2942
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.__nonzero__ (build/cythonized/sage/symbolic/expression.cpp:19523)()
#    2919                 if pynac_result == relational_notimplemented and self.operator()==operator.ne:
#    2920                     return not (self.lhs()-self.rhs()).is_trivial_zero()
# -> 2921                 res = self.test_relation()
#    2922                 if res is True:
#    2923                     return True
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.test_relation (build/cythonized/sage/symbolic/expression.cpp:21566)()
#    3088                     else:
#    3089                         var_dict = dict([(v, domain.random_element()) for v in vars])
# -> 3090                     val = domain(diff.subs(var_dict))
#    3091                     if falsify(val, zero):
#    3092                         return False
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.substitute (build/cythonized/sage/symbolic/expression.cpp:30735)()
#    5333             smap.insert(make_pair((<Expression>self.coerce_in(k))._gobj,
#    5334                                   (<Expression>self.coerce_in(v))._gobj))
# -> 5335         res = self._gobj.subs_map(smap, 0)
#    5336         return new_Expression_from_GEx(self._parent, res)
#    5337
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/rings/rational.pyx in sage.rings.rational.Rational.__add__ (build/cythonized/sage/rings/rational.c:19870)()
#    2307             return x
#    2308
# -> 2309         return coercion_model.bin_op(left, right, operator.add)
#    2310
#    2311     cpdef _add_(self, right):
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/structure/coerce.pyx in sage.structure.coerce.CoercionModel.bin_op (build/cythonized/sage/structure/coerce.c:10120)()
#    1205         # Now coerce to a common parent and do the operation there
#    1206         try:
# -> 1207             xy = self.canonical_coercion(x, y)
#    1208         except TypeError:
#    1209             self._record_exception()
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/structure/coerce.pyx in sage.structure.coerce.CoercionModel.canonical_coercion (build/cythonized/sage/structure/coerce.c:11586)()
#    1316             x_map, y_map = coercions
#    1317             if x_map is not None:
# -> 1318                 x_elt = (<Map>x_map)._call_(x)
#    1319             else:
#    1320                 x_elt = x
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/structure/coerce_maps.pyx in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:4448)()
#     154         cdef Parent C = self._codomain
#     155         try:
# --> 156             return C._element_constructor(x)
#     157         except Exception:
#     158             if print_warnings:
#
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/categories/sets_cat.py in _element_constructor_from_element_class(self, *args, **keywords)
#     972                 return NotImplemented
#     973
# --> 974         def _element_constructor_from_element_class(self, *args, **keywords):
#     975             """
#     976             The default constructor for elements of this parent ``self``.
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
Lie.symbols('x',3)
#res = [1, - x2 - x3, - 2*x1 - 2, x3 - x2, 5*x1 + x2 + 2*x3 + x1*x2 + x1*x3 + x2*x3 + x1^2 + 4, - x1^2 - 3*x1 + x2^2 + x2 - 2, - x1^2 - 3*x1 + x3^2 - x2 - 2, x2 - 3*x1 + x1*x2 + x1*x3 - x2*x3 - x1^2 - 2, x2 - 3*x1 + x1*x2 - x1*x3 + x2*x3 - x1^2 - 2, 5*x1 + x2 - 2*x3 + x1*x2 - x1*x3 - x2*x3 + x1^2 + 4, 8*x1 - 2*x2 + 2*x3 - 2*x1*x2 + 4*x1*x3 - 2*x2*x3 - x1*x2^2 + x1^2*x3 - x2^2*x3 + 5*x1^2 + x1^3 - x2^2 + 4, x2*x3^2 - x2 - 2*x1*x2 - x1^2*x2 - x1*x3^2 - x1 + 2*x1^2 + x1^3 - 2, 13*x1 + 3*x2 + 4*x1*x2 + x1^2*x2 - x1*x3^2 - x2*x3^2 + 6*x1^2 + x1^3 - 2*x3^2 + 8, 8*x1 - 2*x2 - 2*x3 - 2*x1*x2 - 4*x1*x3 + 2*x2*x3 - x1*x2^2 - x1^2*x3 + x2^2*x3 + 5*x1^2 + x1^3 - x2^2 + 4, x1^4 + 7*x1^3 - x1^2*x2^2 - x1^2*x2 - x1^2*x3^2 + 19*x1^2 - 4*x1*x2^2 - 6*x1*x2 - 3*x1*x3^2 + 23*x1 + x2^2*x3^2 - 3*x2^2 + x2*x3^2 - 5*x2 - 2*x3^2 + 10]
res = matrix(res).T
res2 = mat.inverse()*res
res2 = [(i+1,factor(j)) for i,j in enumerate(res2.column(0))]
res = [(i+1,factor(j)) for i,j in enumerate(res.column(0))]

# %%
#过渡矩阵
f = {i+1:j for i,j in enumerate(fs)}
roots = [(3,4,2,2,1),(3,7,2,1),(4,6,2,1),(3,4,2,5),(10,2,1),(6,7,1),(3,2,9),(4,2,8),(3,7,5),(4,6,5),(10,5),(2,11),(6,9),(7,8),(12,)] #录入索引
roots = [tuple(f[i] for i in line) for line in roots] #转字符串
roots = [ide.tuple2element(i) for i in roots] #转pbw元素
keys = [list(i.keys)[0] for i in pbw_basis] #键值
mat = matrix([[root.element[key] if key in root else 0 for root in roots] for key in keys])

# %%
table(res)
table(res2)
