# %% [raw]
# .plot() # 直接绘图
# .plot().show(figsize=10) # 指定图像大小
# .plot 参数
#     fundamental_weights
#     roots
#     bounding_box
#     reflection_hyperplanes
#     alcoves
#     alcove_labels

# %%
"""有限根系与仿射根系"""
V = RootSystem(["A",2]).ambient_space() # 有限型根系
Va = RootSystem(["A",2,1]).ambient_space() # 仿射型根系
V3 = RootSystem(["A",3]).ambient_space() # 有限型根系
Va3 = RootSystem(["A",3,1]).ambient_space() # 仿射型根系

# %%
"""仿射型alcove绘制"""
Va.plot(alcoves=True,alcove_labels=True,bounding_box=3,
       fundamental_weights=False,roots=False,
        reflection_hyperplanes=False).show(figsize=8)
# Out:
# Graphics object consisting of 235 graphics primitives

# %%
"""仿射截面框线图"""
p = Va.plot(affine=False,level=1)
p.show(aspect_ratio=[1,1,2], frame=False) # 去除边框
# Out:
# Graphics3d Object

# %%
"""三维根系"""
Va3.plot(reflection_hyperplanes=False, bounding_box=85/100)
# Out:
# Graphics3d Object

# %%
"""绘制选定alcove"""
W = Va3.weyl_group()
Va3.plot(reflection_hyperplanes=False,
       alcoves=[W.one()], bounding_box=2)
# Out:
# Graphics3d Object

# %%
"""绘制框线图"""
Va3.plot(reflection_hyperplanes=False,
       alcoves=[W.coxeter_element()], bounding_box=2)
# Out:
# Graphics3d Object
