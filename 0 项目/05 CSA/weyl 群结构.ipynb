# %%
load('csa.sage')
load('bilinear_form.sage')
load('group_tree.sage')

# %%
s,n = "A",6
cartan_type = CartanType([s,n])
csa = CSA(cartan_type)
fws = csa.fundamental_weights_check()
res = []
for i in range(n):
    res.append([s,n,i+1])
    res.extend([csa.ascending_chain(-fws[i]-fws[j]) for j in range(n)])

# %%
table(res)
# Out:
#   A   6   1
#   1   2   3
#   1   2   1
#   1   2   3
#   1   2   3
#   1   2   3
#   1   2   3
#   A   6   2
#   1   2   1
#   2   1   3
#   2   1   3
#   2   1   3
#   2   1   3
#   2   1   3
#   A   6   3
#   1   2   3
#   2   1   3
#   3   2   1
#   3   2   1
#   3   2   1
#   3   2   1
#   A   6   4
#   1   2   3
#   2   1   3
#   3   2   1
#   4   3   2
#   4   3   2
#   4   3   2
#   A   6   5
#   1   2   3
#   2   1   3
#   3   2   1
#   4   3   2
#   5   4   3
#   5   4   3
#   A   6   6
#   1   2   3
#   2   1   3
#   3   2   1
#   4   3   2
#   5   4   3
#   6   5   4

# %%
# Out:
#   1   2   3   4   5
#   1   2   1   3   2
#   1   2   3   2   1
#   1   2   3   4   3
#   1   2   3   4   5
